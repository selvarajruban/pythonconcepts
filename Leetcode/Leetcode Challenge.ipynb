# %%
s= Solution()
lst = [7,1,0,4,9,3,2,2,2,3,1,6,5,1,2,5,7,1,7,7,7,5,2,3,7,6,3,0,4,2,7,5,8,8,7,1,8,6,3,9,3,8,5,0,6,3,6,3,1,5,8,2,9,7,1,8,8,6,1,2,7,5,3,0,1,6,5,3,8,7,6,0,5,0,1,5,5,6,8,9,1,3,9,7,3,1,1,7,1,0,2,8,5,4,4,0,8,5,6,5]
s.findEvenNumbers(lst)
# [102,120,130,132,210,230,302,310,312,320]
# Out:
# [100,
#  102,
#  104,
#  106,
#  108,
#  110,
#  112,
#  114,
#  116,
#  118,
#  120,
#  122,
#  124,
#  126,
#  128,
#  130,
#  132,
#  134,
#  136,
#  138,
#  140,
#  142,
#  144,
#  146,
#  148,
#  150,
#  152,
#  154,
#  156,
#  158,
#  160,
#  162,
#  164,
#  166,
#  168,
#  170,
#  172,
#  174,
#  176,
#  178,
#  180,
#  182,
#  184,
#  186,
#  188,
#  190,
#  192,
#  194,
#  196,
#  198,
#  200,
#  202,
#  204,
#  206,
#  208,
#  210,
#  212,
#  214,
#  216,
#  218,
#  220,
#  222,
#  224,
#  226,
#  228,
#  230,
#  232,
#  234,
#  236,
#  238,
#  240,
#  242,
#  244,
#  246,
#  248,
#  250,
#  252,
#  254,
#  256,
#  258,
#  260,
#  262,
#  264,
#  266,
#  268,
#  270,
#  272,
#  274,
#  276,
#  278,
#  280,
#  282,
#  284,
#  286,
#  288,
#  290,
#  292,
#  294,
#  296,
#  298,
#  300,
#  302,
#  304,
#  306,
#  308,
#  310,
#  312,
#  314,
#  316,
#  318,
#  320,
#  322,
#  324,
#  326,
#  328,
#  330,
#  332,
#  334,
#  336,
#  338,
#  340,
#  342,
#  344,
#  346,
#  348,
# ...

# %%
# Leetcode Challenge
class Solution(object):
    def findEvenNumbers(self, digits):
        """
        :type digits: List[int]
        :rtype: List[int]
        """
        result = []
        
        for i in range(len(digits)):
            for j in range(len(digits)):
                for k in range(len(digits)):
                    if i != j and j != k and i!= k:
                        num = str(digits[i]) + str(digits[j]) + str(digits[k])
                        if int(num)%2 == 0 and num[0] != '0' and len(num) == 3:
                                     result.append(int(num))
        
        res = list(set(result))
        res.sort()
        return res;

# %%
import math
# Definition for singly-linked list.
# class ListNode(object):
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution(object):
    def deleteMiddle(self, head):
        """
        :type head: Optional[ListNode]
        :rtype: Optional[ListNode]
        """
        mid = math.floor(len(head)/2) + 1
        del (head[mid-1])
        
        return head

# %%
s= Solution()
lst = [2,1]
s.deleteMiddle(lst)
# [102,120,130,132,210,230,302,310,312,320]
# Out:
# [2]
